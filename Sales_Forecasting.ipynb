# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('FMCG_2022_2024.csv')
df
# Out:
#               date     sku     brand        segment  category     channel  \
# 0       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 1       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 2       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 3       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk    Discount
# 4       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk    Discount
# ...            ...     ...       ...            ...       ...         ...
# 190752  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar    Discount
# 190753  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar    Discount
# 190754  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
# 190755  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
# 190756  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
#
#             region  pack_type  price_unit  promotion_flag  delivery_days  \
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#               date     sku     brand        segment  category     channel  \
# 0       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 1       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 2       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk      Retail
# 3       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk    Discount
# 4       2022-01-21  MI-006  MiBrand1      Milk-Seg3      Milk    Discount
# ...            ...     ...       ...            ...       ...         ...
# 190752  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar    Discount
# 190753  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar    Discount
# 190754  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
# 190755  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
# 190756  2024-12-31  SN-030  SnBrand2  SnackBar-Seg1  SnackBar  E-commerce
#
#             region  pack_type  price_unit  promotion_flag  delivery_days  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190757 entries, 0 to 190756
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   date             190757 non-null  object
#  1   sku              190757 non-null  object
#  2   brand            190757 non-null  object
#  3   segment          190757 non-null  object
#  4   category         190757 non-null  object
#  5   channel          190757 non-null  object
#  6   region           190757 non-null  object
#  7   pack_type        190757 non-null  object
#  8   price_unit       190757 non-null  float64
#  9   promotion_flag   190757 non-null  int64
#  10  delivery_days    190757 non-null  int64
#  11  stock_available  190757 non-null  int64
#  12  delivered_qty    190757 non-null  int64
#  13  units_sold       190757 non-null  int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 20.4+ MB

# %%
df_measures = df.describe()
df_measures
# Out:
#           price_unit  promotion_flag  delivery_days  stock_available  \
# count  190757.000000   190757.000000  190757.000000    190757.000000
# mean        5.251979        0.149200       3.004860       157.697652
# std         2.166705        0.356287       1.414626        52.736104
# min         1.500000        0.000000       1.000000       -12.000000
# 25%         3.380000        0.000000       2.000000       124.000000
# 50%         5.250000        0.000000       3.000000       155.000000
# 75%         7.130000        0.000000       4.000000       192.000000
# max         9.000000        1.000000       5.000000       405.000000
#
#        delivered_qty     units_sold
# count  190757.000000  190757.000000
# mean      179.333655      19.919709
# std        40.037475      11.770077
# min       -11.000000     -25.000000
# 25%       152.000000      12.000000
# 50%       179.000000      18.000000
# 75%       206.000000      25.000000
# max       366.000000     139.000000

# %%
df.isnull().sum()
# Out:
# date               0
# sku                0
# brand              0
# segment            0
# category           0
# channel            0
# region             0
# pack_type          0
# price_unit         0
# promotion_flag     0
# delivery_days      0
# stock_available    0
# delivered_qty      0
# units_sold         0
# dtype: int64

# %%
df.nunique()
# Out:
# date               1076
# sku                  30
# brand                14
# segment              13
# category              5
# channel               3
# region                3
# pack_type             3
# price_unit          751
# promotion_flag        2
# delivery_days         5
# stock_available     355
# delivered_qty       321
# units_sold          135
# dtype: int64

# %%
top_delivered_qty = df.sort_values(by='delivered_qty', ascending=False).head(10)
top_delivered_qty
# Out:
#               date     sku     brand         segment   category     channel  \
# 26170   2022-12-12  YO-001  YoBrand3     Yogurt-Seg1     Yogurt      Retail
# 73450   2023-08-08  YO-016  YoBrand3     Yogurt-Seg3     Yogurt    Discount
# 145982  2024-06-19  SN-030  SnBrand2   SnackBar-Seg1   SnackBar      Retail
# 119283  2024-02-24  RE-007  ReBrand4  ReadyMeal-Seg1  ReadyMeal    Discount
# 124314  2024-03-17  RE-007  ReBrand4  ReadyMeal-Seg1  ReadyMeal    Discount
# 114157  2024-02-01  MI-026  MiBrand4       Milk-Seg2       Milk  E-commerce
# 154341  2024-07-26  YO-009  YoBrand4     Yogurt-Seg1     Yogurt  E-commerce
# 126463  2024-03-26  YO-018  YoBrand2     Yogurt-Seg1     Yogurt    Discount
# 78756   2023-08-31  YO-018  YoBrand2     Yogurt-Seg1     Yogurt    Discount
# 23041   2022-11-20  RE-007  ReBrand4  ReadyMeal-Seg1  ReadyMeal    Discount
#
#             region  pack_type  price_unit  promotion_flag  delivery_days  \
# ...

# %%
top_units_sold = df.sort_values(by='units_sold', ascending=False).head(10)
top_units_sold
# Out:
#               date     sku     brand         segment   category     channel  \
# 69036   2023-07-20  SN-019  SnBrand2   SnackBar-Seg1   SnackBar    Discount
# 36864   2023-02-16  YO-016  YoBrand3     Yogurt-Seg3     Yogurt    Discount
# 5540    2022-06-04  YO-012  YoBrand1     Yogurt-Seg2     Yogurt    Discount
# 60146   2023-06-11  YO-024  YoBrand2     Yogurt-Seg3     Yogurt    Discount
# 8176    2022-07-06  YO-012  YoBrand1     Yogurt-Seg2     Yogurt      Retail
# 36707   2023-02-15  RE-017  ReBrand2  ReadyMeal-Seg2  ReadyMeal  E-commerce
# 38475   2023-02-25  YO-016  YoBrand3     Yogurt-Seg3     Yogurt    Discount
# 6138    2022-06-12  YO-001  YoBrand3     Yogurt-Seg1     Yogurt  E-commerce
# 37274   2023-02-18  RE-025  ReBrand2  ReadyMeal-Seg3  ReadyMeal  E-commerce
# 145194  2024-06-16  YO-016  YoBrand3     Yogurt-Seg3     Yogurt  E-commerce
#
#             region  pack_type  price_unit  promotion_flag  delivery_days  \
# ...

# %%
top_price_unit = df.sort_values(by='price_unit', ascending=False).head(10)
top_price_unit
# Out:
#               date     sku     brand         segment   category     channel  \
# 142266  2024-06-03  RE-025  ReBrand2  ReadyMeal-Seg3  ReadyMeal      Retail
# 52288   2023-05-07  SN-028  SnBrand2   SnackBar-Seg1   SnackBar      Retail
# 75336   2023-08-16  YO-024  YoBrand2     Yogurt-Seg3     Yogurt      Retail
# 109818  2024-01-14  RE-004  ReBrand1  ReadyMeal-Seg2  ReadyMeal    Discount
# 26886   2022-12-16  MI-022  MiBrand3       Milk-Seg2       Milk      Retail
# 9207    2022-07-18  YO-001  YoBrand3     Yogurt-Seg1     Yogurt  E-commerce
# 190692  2024-12-31  MI-022  MiBrand3       Milk-Seg2       Milk      Retail
# 178424  2024-11-08  MI-006  MiBrand1       Milk-Seg3       Milk    Discount
# 30442   2023-01-08  MI-023  MiBrand3       Milk-Seg3       Milk      Retail
# 164061  2024-09-06  SN-028  SnBrand2   SnackBar-Seg1   SnackBar      Retail
#
#             region  pack_type  price_unit  promotion_flag  delivery_days  \
# ...

# %%
most_availablw_stock = df.sort_values(by='stock_available', ascending=False).head(10)
most_availablw_stock
# Out:
#               date     sku     brand         segment   category     channel  \
# 119283  2024-02-24  RE-007  ReBrand4  ReadyMeal-Seg1  ReadyMeal    Discount
# 73039   2023-08-06  YO-024  YoBrand2     Yogurt-Seg3     Yogurt      Retail
# 124314  2024-03-17  RE-007  ReBrand4  ReadyMeal-Seg1  ReadyMeal    Discount
# 126463  2024-03-26  YO-018  YoBrand2     Yogurt-Seg1     Yogurt    Discount
# 58881   2023-06-06  MI-008  MiBrand3       Milk-Seg2       Milk  E-commerce
# 164114  2024-09-07  RE-004  ReBrand1  ReadyMeal-Seg2  ReadyMeal  E-commerce
# 109905  2024-01-14  RE-015  ReBrand4  ReadyMeal-Seg1  ReadyMeal    Discount
# 47018   2023-04-13  RE-007  ReBrand4  ReadyMeal-Seg1  ReadyMeal    Discount
# 34332   2023-02-01  RE-015  ReBrand4  ReadyMeal-Seg1  ReadyMeal    Discount
# 55444   2023-05-22  MI-002  MiBrand2       Milk-Seg1       Milk      Retail
#
#             region  pack_type  price_unit  promotion_flag  delivery_days  \
# ...

# %%
gpd = df.groupby('date')
gpd = gpd.mean(numeric_only=True)
gpd
# Out:
#             price_unit  promotion_flag  delivery_days  stock_available  \
# date
# 2022-01-21    4.828750        0.250000       2.875000       123.125000
# 2022-01-22    5.205833        0.083333       2.916667       171.333333
# 2022-01-23    5.342857        0.142857       3.428571       172.214286
# 2022-01-24    5.574615        0.076923       2.538462       161.615385
# 2022-01-25    4.948667        0.066667       3.066667       146.933333
# ...                ...             ...            ...              ...
# 2024-12-27    5.191702        0.131915       3.000000       158.914894
# 2024-12-28    5.091053        0.127193       2.973684       155.153509
# 2024-12-29    5.334292        0.167382       3.145923       160.523605
# 2024-12-30    5.430304        0.147826       2.969565       160.447826
# 2024-12-31    5.168230        0.141593       2.995575       150.774336
#
#             delivered_qty  units_sold
# date
# 2022-01-21     153.875000   10.625000
# ...

# %%
gpdt = gpd.transpose()
gpdt
# Out:
# date             2022-01-21  2022-01-22  2022-01-23  2022-01-24  2022-01-25  \
# price_unit          4.82875    5.205833    5.342857    5.574615    4.948667
# promotion_flag      0.25000    0.083333    0.142857    0.076923    0.066667
# delivery_days       2.87500    2.916667    3.428571    2.538462    3.066667
# stock_available   123.12500  171.333333  172.214286  161.615385  146.933333
# delivered_qty     153.87500  180.916667  171.071429  178.769231  165.200000
# units_sold         10.62500   13.916667   14.071429   11.538462   11.400000
#
# date             2022-01-26  2022-01-27  2022-01-28  2022-01-29  2022-01-30  \
# price_unit           4.4500    4.348667     6.01125    5.040000    5.153846
# promotion_flag       0.1250    0.066667     0.25000    0.176471    0.230769
# delivery_days        3.1875    2.200000     3.50000    2.352941    3.153846
# stock_available    145.5000  149.600000   176.93750  148.000000  151.615385
# ...

# %%
gpdt.plot(kind='line',legend=False)
# Out:
# <Axes: >

# %%
gpb = df.groupby('brand').mean(numeric_only=True)
gpb
# Out:
#           price_unit  promotion_flag  delivery_days  stock_available  \
# brand
# JuBrand3    5.265496        0.148783       3.028374       157.971626
# MiBrand1    5.234004        0.146438       3.005732       157.686640
# MiBrand2    5.235919        0.158279       3.004144       157.241366
# MiBrand3    5.217864        0.142254       2.992923       157.802282
# MiBrand4    5.224004        0.150925       2.989776       157.175755
# ReBrand1    5.270156        0.148894       2.989271       157.708884
# ReBrand2    5.279955        0.147981       3.001363       158.545067
# ReBrand4    5.267214        0.146213       3.004981       157.354628
# SnBrand2    5.246808        0.147563       3.011578       157.631895
# SnBrand3    5.240176        0.145065       3.017815       158.339938
# YoBrand1    5.255596        0.150498       3.000925       157.499289
# YoBrand2    5.256335        0.148251       3.017292       157.785405
# ...

# %%
gpb.plot(kind='bar')
# Out:
# <Axes: xlabel='brand'>

# %%
gpc = df.groupby('category').mean(numeric_only=True)
gpc
# Out:
#            price_unit  promotion_flag  delivery_days  stock_available  \
# category
# Juice        5.265496        0.148783       3.028374       157.971626
# Milk         5.225782        0.146900       2.997376       157.589192
# ReadyMeal    5.272239        0.147418       3.000234       157.841862
# SnackBar     5.245678        0.147137       3.012641       157.752572
# Yogurt       5.260013        0.152406       3.005928       157.645729
#
#            delivered_qty  units_sold
# category
# Juice         179.416823   17.909981
# Milk          179.138177   17.552057
# ReadyMeal     179.364470   19.828076
# SnackBar      179.391777   20.055924
# Yogurt        179.405298   21.546509

# %%
gpc.plot(kind='bar')
# Out:
# <Axes: xlabel='category'>
